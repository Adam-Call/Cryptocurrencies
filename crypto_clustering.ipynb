# %% [markdown]
# # Clustering Crypto

# %%
# Initial imports
# !pip install hvplot
# !pip install Path
import pandas as pd
import hvplot.pandas
from path import Path
import plotly.express as px
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %% [markdown]
# ### Deliverable 1: Preprocessing the Data for PCA

# %%
# Load the crypto_data.csv dataset.
from google.colab import files
import io

uploaded = files.upload()
crypto_df = pd.read_csv(io.BytesIO(uploaded['crypto_data.csv']))
crypto_df.head()
# Out:
#      <input type="file" id="files-24f4ba9b-a190-4ffb-97d5-c37373014dd7" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-24f4ba9b-a190-4ffb-97d5-c37373014dd7">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving crypto_data.csv to crypto_data.csv
#   Unnamed: 0   CoinName Algorithm  ...  ProofType TotalCoinsMined  TotalCoinSupply
# 0         42    42 Coin    Scrypt  ...    PoW/PoS    4.199995e+01               42
# 1        365    365Coin       X11  ...    PoW/PoS             NaN       2300000000
# 2        404    404Coin    Scrypt  ...    PoW/PoS    1.055185e+09        532000000
# 3        611  SixEleven   SHA-256  ...        PoW             NaN           611000
# 4        808        808   SHA-256  ...    PoW/PoS    0.000000e+00                0
#
# ...

# %%
#view datatypes
crypto_df.dtypes
# Out:
# Unnamed: 0          object
# CoinName            object
# Algorithm           object
# IsTrading             bool
# ProofType           object
# TotalCoinsMined    float64
# TotalCoinSupply     object
# dtype: object

# %%
# Keep all the cryptocurrencies that are being traded.
trading = crypto_df[crypto_df.IsTrading == True]
trading.head()
# Out:
#   Unnamed: 0   CoinName Algorithm  ...  ProofType TotalCoinsMined  TotalCoinSupply
# 0         42    42 Coin    Scrypt  ...    PoW/PoS    4.199995e+01               42
# 1        365    365Coin       X11  ...    PoW/PoS             NaN       2300000000
# 2        404    404Coin    Scrypt  ...    PoW/PoS    1.055185e+09        532000000
# 3        611  SixEleven   SHA-256  ...        PoW             NaN           611000
# 4        808        808   SHA-256  ...    PoW/PoS    0.000000e+00                0
#
# [5 rows x 7 columns]

# %%
# Keep all the cryptocurrencies that have a working algorithm.
# YOUR CODE HERE

# %%
# Remove the "IsTrading" column. 
trading = trading.drop(columns='IsTrading')
trading.head()
# Out:
#   Unnamed: 0   CoinName Algorithm ProofType  TotalCoinsMined TotalCoinSupply
# 0         42    42 Coin    Scrypt   PoW/PoS     4.199995e+01              42
# 1        365    365Coin       X11   PoW/PoS              NaN      2300000000
# 2        404    404Coin    Scrypt   PoW/PoS     1.055185e+09       532000000
# 3        611  SixEleven   SHA-256       PoW              NaN          611000
# 4        808        808   SHA-256   PoW/PoS     0.000000e+00               0

# %%
# Remove rows that have at least 1 null value.
trading.dropna()
# Out:
#      Unnamed: 0     CoinName  ... TotalCoinsMined TotalCoinSupply
# 0            42      42 Coin  ...    4.199995e+01              42
# 2           404      404Coin  ...    1.055185e+09       532000000
# 4           808          808  ...    0.000000e+00               0
# 5          1337    EliteCoin  ...    2.927942e+10    314159265359
# 7           BTC      Bitcoin  ...    1.792718e+07        21000000
# ...         ...          ...  ...             ...             ...
# 1238       ZEPH       ZEPHYR  ...    2.000000e+09      2000000000
# 1242        GAP      Gapcoin  ...    1.493105e+07       250000000
# 1245        BDX       Beldex  ...    9.802226e+08      1400222610
# 1246        ZEN      Horizen  ...    7.296538e+06        21000000
# 1247        XBC  BitcoinPlus  ...    1.283270e+05         1000000
#
# [685 rows x 6 columns]

# %%
# Keep the rows where coins are mined.
crypto_df = trading[trading.TotalCoinsMined > 0]
crypto_df
# Out:
#      Unnamed: 0     CoinName  ... TotalCoinsMined TotalCoinSupply
# 0            42      42 Coin  ...    4.199995e+01              42
# 2           404      404Coin  ...    1.055185e+09       532000000
# 5          1337    EliteCoin  ...    2.927942e+10    314159265359
# 7           BTC      Bitcoin  ...    1.792718e+07        21000000
# 8           ETH     Ethereum  ...    1.076842e+08               0
# ...         ...          ...  ...             ...             ...
# 1238       ZEPH       ZEPHYR  ...    2.000000e+09      2000000000
# 1242        GAP      Gapcoin  ...    1.493105e+07       250000000
# 1245        BDX       Beldex  ...    9.802226e+08      1400222610
# 1246        ZEN      Horizen  ...    7.296538e+06        21000000
# 1247        XBC  BitcoinPlus  ...    1.283270e+05         1000000
#
# [532 rows x 6 columns]

# %%
# Create a new DataFrame that holds only the cryptocurrencies names.
coin_name = pd.DataFrame(crypto_df['CoinName'])
coin_name
# Out:
#          CoinName
# 0         42 Coin
# 2         404Coin
# 5       EliteCoin
# 7         Bitcoin
# 8        Ethereum
# ...           ...
# 1238       ZEPHYR
# 1242      Gapcoin
# 1245       Beldex
# 1246      Horizen
# 1247  BitcoinPlus
#
# [532 rows x 1 columns]

# %%
# Drop the 'CoinName' column since it's not going to be used on the clustering algorithm.
crypto_df = crypto_df.drop(columns='CoinName')
crypto_df.head()
# Out:
#   Unnamed: 0 Algorithm ProofType  TotalCoinsMined TotalCoinSupply
# 0         42    Scrypt   PoW/PoS     4.199995e+01              42
# 2        404    Scrypt   PoW/PoS     1.055185e+09       532000000
# 5       1337       X13   PoW/PoS     2.927942e+10    314159265359
# 7        BTC   SHA-256       PoW     1.792718e+07        21000000
# 8        ETH    Ethash       PoW     1.076842e+08               0

# %%
# Use get_dummies() to create variables for text features.
X = pd.get_dummies(crypto_df, columns=['Algorithm', 'ProofType']) 
X.head()
# Out:
#   Unnamed: 0  ...  ProofType_dPoW/PoW
# 0         42  ...                   0
# 2        404  ...                   0
# 5       1337  ...                   0
# 7        BTC  ...                   0
# 8        ETH  ...                   0
#
# [5 rows x 99 columns]

# %%
X['TotalCoinSupply'] = pd.to_numeric(X['TotalCoinSupply'])
X.head()
# Out:
#   Unnamed: 0  ...  ProofType_dPoW/PoW
# 0         42  ...                   0
# 2        404  ...                   0
# 5       1337  ...                   0
# 7        BTC  ...                   0
# 8        ETH  ...                   0
#
# [5 rows x 99 columns]

# %%
X = X.set_index('Unnamed: 0')
X.head()
# Out:
#             TotalCoinsMined  ...  ProofType_dPoW/PoW
# Unnamed: 0                   ...
# 42             4.199995e+01  ...                   0
# 404            1.055185e+09  ...                   0
# 1337           2.927942e+10  ...                   0
# BTC            1.792718e+07  ...                   0
# ETH            1.076842e+08  ...                   0
#
# [5 rows x 98 columns]

# %%
X_index = X.index
X_index
# Out:
# Index(['42', '404', '1337', 'BTC', 'ETH', 'LTC', 'DASH', 'XMR', 'ETC', 'ZEC',
#        ...
#        'TCH', 'WAVES', 'PART', 'BTT', 'NXT', 'ZEPH', 'GAP', 'BDX', 'ZEN',
#        'XBC'],
#       dtype='object', name='Unnamed: 0', length=532)

# %%
# Standardize the data with StandardScaler().
X_scaled = StandardScaler().fit_transform(X)

# %% [markdown]
# ### Deliverable 2: Reducing Data Dimensions Using PCA

# %%
# Using PCA to reduce dimension to three principal components.
pca = PCA(n_components=3)
crypto_pca = pca.fit_transform(X_scaled)
crypto_pca
# Out:
# array([[-0.33355588,  1.02810428, -0.44872105],
#        [-0.31688922,  1.02832907, -0.449099  ],
#        [ 2.29494347,  1.61963913, -0.63950304],
#        ...,
#        [ 0.32917793, -2.2828544 ,  0.39861062],
#        [-0.16274908, -1.95781989,  0.30853749],
#        [-0.28640159,  0.85158143, -0.27696377]])

# %%
# Create a DataFrame with the three principal components.
pcs_df = pd.DataFrame(
    data=crypto_pca, index= X_index, columns=['PC 1', 'PC 2', 'PC 3']
)

pcs_df.head()
# Out:
#                 PC 1      PC 2      PC 3
# Unnamed: 0
# 42         -0.333556  1.028104 -0.448721
# 404        -0.316889  1.028329 -0.449099
# 1337        2.294943  1.619639 -0.639503
# BTC        -0.145556 -1.346917  0.098738
# ETH        -0.141288 -2.006971  0.274379

# %% [markdown]
# ### Deliverable 3: Clustering Crytocurrencies Using K-Means
#
# #### Finding the Best Value for `k` Using the Elbow Curve

# %%
import os, holoviews as hv
os.environ['HV_DOC_HTML'] = 'true'

# %%
# Create an elbow curve to find the best value for K.
hv.extension('bokeh')
# Find the best value for K
inertia = []
k = list(range(1, 11))

# Calculate the inertia for the range of K values
for i in k:
    km = KMeans(n_clusters=i, random_state=0)
    km.fit(pcs_df)
    inertia.append(km.inertia_)

# Create the elbow curve
elbow_data = {"k": k, "inertia": inertia}
df_elbow = pd.DataFrame(elbow_data)
df_elbow.hvplot.line(x="k", y="inertia", xticks=k, title="Elbow Curve")
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %% [markdown]
# Running K-Means with `k=4`

# %%
# Initialize the K-Means model.
model = KMeans(n_clusters=4, random_state=0)

# Fit the model
model.fit(pcs_df)

# Predict clusters
predictions = model.predict(pcs_df)

# %%
pcs_df = pcs_df.reset_index()
pcs_df.head()
# Out:
#   Unnamed: 0      PC 1      PC 2      PC 3
# 0         42 -0.333556  1.028104 -0.448721
# 1        404 -0.316889  1.028329 -0.449099
# 2       1337  2.294943  1.619639 -0.639503
# 3        BTC -0.145556 -1.346917  0.098738
# 4        ETH -0.141288 -2.006971  0.274379

# %%
crypto_df.head()
# Out:
#   Unnamed: 0 Algorithm ProofType  TotalCoinsMined TotalCoinSupply
# 0         42    Scrypt   PoW/PoS     4.199995e+01              42
# 2        404    Scrypt   PoW/PoS     1.055185e+09       532000000
# 5       1337       X13   PoW/PoS     2.927942e+10    314159265359
# 7        BTC   SHA-256       PoW     1.792718e+07        21000000
# 8        ETH    Ethash       PoW     1.076842e+08               0

# %%
# Create a new DataFrame including predicted clusters and cryptocurrencies features.
# Concatentate the crypto_df and pcs_df DataFrames on the same columns.
clustered_df = pd.merge(left=crypto_df, right=pcs_df, how='inner')

#  Add a new column, "CoinName" to the clustered_df DataFrame that holds the names of the cryptocurrencies. 
clustered_df['CoinName'] = coin_name

#  Add a new column, "Class" to the clustered_df DataFrame that holds the predictions.
clustered_df['class'] = model.labels_

#drop unused columns
#clustered_df = clustered_df.drop(columns=['level_0', 'index'])

#set index
clustered_df = clustered_df.set_index('Unnamed: 0')

#reorder columns
clustered_df=clustered_df[['CoinName', 'Algorithm', "ProofType", 'TotalCoinsMined', 'TotalCoinSupply', 'PC 1', 'PC 2', 'PC 3', 'class']]

# Print the shape of the clustered_df
print(clustered_df.shape)
clustered_df.head(10)
# Out:
# (532, 9)
#              CoinName       Algorithm ProofType  ...      PC 2      PC 3  class
# Unnamed: 0                                       ...
# 42            42 Coin          Scrypt   PoW/PoS  ...  1.028104 -0.448721      0
# 404               NaN          Scrypt   PoW/PoS  ...  1.028329 -0.449099      0
# 1337          404Coin             X13   PoW/PoS  ...  1.619639 -0.639503      0
# BTC               NaN         SHA-256       PoW  ... -1.346917  0.098738      1
# ETH               NaN          Ethash       PoW  ... -2.006971  0.274379      1
# LTC         EliteCoin          Scrypt       PoW  ... -1.108067  0.035256      1
# DASH              NaN             X11   PoW/PoS  ...  1.220139 -0.388102      0
# XMR           Bitcoin  CryptoNight-V7       PoW  ... -2.235920  0.332576      1
# ETC          Ethereum          Ethash       PoW  ... -2.007060  0.274372      1
# ZEC          Litecoin        Equihash       PoW  ... -1.957820  0.308537      1
#
# [10 rows x 9 columns]

# %% [markdown]
# ### Deliverable 4: Visualizing Cryptocurrencies Results
#
# #### 3D-Scatter with Clusters

# %%
# Creating a 3D-Scatter with the PCA data and the clusters
hv.extension('bokeh')
fig = px.scatter_3d(
    clustered_df,
    x='PC 1',
    y='PC 2',
    z='PC 3',
    color='class',
    symbol='class',
    width=800
)
fig.update_layout(legend=dict(x=0, y=1))
fig.show()
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
# Create a table with tradable cryptocurrencies.
hv.extension('bokeh')
clustered_df.hvplot.table(sortable=True, selectable=True)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
# Print the total number of tradable cryptocurrencies.

print(f'Total number of tradeable currencies: {len(clustered_df.CoinName)}')
# Out:
# Total number of tradeable currencies: 532

# %%
#create new plot_df 
plot_df = clustered_df.copy()
plot_df = plot_df.drop(columns=['Algorithm', 'ProofType', 'PC 1', 'PC 2', 'PC 3'])
plot_df.head()
# Out:
#            CoinName  TotalCoinsMined TotalCoinSupply  class
# Unnamed: 0
# 42          42 Coin     4.199995e+01              42      0
# 404             NaN     1.055185e+09       532000000      0
# 1337        404Coin     2.927942e+10    314159265359      0
# BTC             NaN     1.792718e+07        21000000      1
# ETH             NaN     1.076842e+08               0      1

# %%
#use MinMaxScaler to standardize data
scaler = MinMaxScaler(feature_range=(0,1))
plot_df['TotalCoinsMined']=scaler.fit_transform(plot_df[['TotalCoinsMined']])
plot_df['TotalCoinSupply']=scaler.fit_transform(plot_df[['TotalCoinSupply']])
plot_df.head()
# Out:
#            CoinName  TotalCoinsMined  TotalCoinSupply  class
# Unnamed: 0
# 42          42 Coin         0.000000     4.200000e-11      0
# 404             NaN         0.001066     5.320000e-04      0
# 1337        404Coin         0.029576     3.141593e-01      0
# BTC             NaN         0.000018     2.100000e-05      1
# ETH             NaN         0.000109     0.000000e+00      1

# %%
# Create a hvplot.scatter plot using x="TotalCoinsMined" and y="TotalCoinSupply".
hv.extension('bokeh')
# x=plot_df["TotalCoinsMined"]
# y=plot_df["TotalCoinSupply"]

plot_df.hvplot.scatter(x='TotalCoinsMined', y='TotalCoinSupply', by='class', hover_cols='CoinName')
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
# Scaling data to create the scatter plot with tradable cryptocurrencies.
scaler = MinMaxScaler(feature_range=(0,1))
# data1 = [clustered_df.TotalCoinsMined]
# data2 = [clustered_df.TotalCoinSupply
mined_scaled_data = scaler.fit_transform(clustered_df[['TotalCoinsMined']])
supply_scaled_data = scaler.fit_transform(clustered_df[['TotalCoinSupply']])
# scaler.fit_transform(clustered_df)

# %%
# Create a new DataFrame that has the scaled data with the clustered_df DataFrame index.
plot_df = pd.DataFrame(mined_scaled_data, supply_scaled_data)

# Add the "CoinName" column from the clustered_df DataFrame to the new DataFrame.
plot_df['CoinName'] = coin_name

# Add the "Class" column from the clustered_df DataFrame to the new DataFrame. 
plot_df['class'] = clustered_df['class']

plot_df.head(10)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-47-8acc573d7853> in <module>()
#       1 # Create a new DataFrame that has the scaled data with the clustered_df DataFrame index.
# ----> 2 plot_df = pd.DataFrame(mined_scaled_data, supply_scaled_data)
#       3
#       4 # Add the "CoinName" column from the clustered_df DataFrame to the new DataFrame.
#       5 plot_df['CoinName'] = coin_name
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     495                 mgr = init_dict({data.name: data}, index, columns, dtype=dtype)
#     496             else:
# --> 497                 mgr = init_ndarray(data, index, columns, dtype=dtype, copy=copy)
#     498
#     499         # For data is list-like, or Iterable (will consume into list)
#
# ...
